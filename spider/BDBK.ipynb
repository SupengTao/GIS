# %%
# city_path = './all_city.txt'
# river_path = './river.txt'
# school_path = './all_school.txt'
# spot_path = './all_spot.txt'
country_path ='./all_country.txt'

# %%
def get_citys():
    citys = []
    with open (city_path, 'r') as f:
        lines = f.readlines()
        for line in lines:
            citys.extend(line.split())
    return citys
def get_rivers():
    rivers = []
    with open(river_path, 'r') as f:
        lines = f.readlines()
        for line in lines:
            rivers.extend(line.split('、'))
    return rivers

def get_schools():
    schools = []
    with open (school_path, 'r') as f:
        lines = f.readlines()
        for line in lines:
            schools.extend(line.split())
    return schools
def get_spots():
    spots = []
    with open (spot_path, 'r') as f:
        lines = f.readlines()
        for line in lines:
            spots.extend(line.split())
    return spots
def get_countrys():
    countrys = []
    with open (country_path, 'r') as f:
        lines = f.readlines()
        for line in lines:
            countrys.extend(line.split())
    return countrys

# %%
# citys = get_citys()
# rivers = get_rivers()
# schools = get_schools()
start_url = 'https://baike.baidu.com/item/'
# city_urls = [start_url + city for city in citys]
# river_urls = [start_url + river for river in rivers]
# school_urls = [start_url + school for school in schools]
# spot_urls = [start_url + spot for spot in all_spots]
country = get_countrys()
country_url = [start_url + c for c in country]

# %%
import bs4
import re
from bs4 import BeautifulSoup
import requests

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.10 Safari/537.36'}

# %%
def get_data(url, headers):
    try:
        r = requests.get(url,headers = headers)
        r.raise_for_status()
    except requests.RequestException as e:
        print(e)
        return None
    else:
        html = r.text.encode(r.encoding).decode()
        soup = BeautifulSoup(html,'lxml')
        name = soup.find_all('dt',class_= 'basicInfo-item name')
        values = soup.find_all('dd',class_= 'basicInfo-item value')
        names = list(map(lambda key:key.text.replace('\xa0',''), name))
        values = list(map(lambda value: re.sub('\\n\[.*]', '',value.text.strip()), values))
        data = list(zip(names, values))
        data = {name:value for name, value in data}
        return data

# %%
country_url
# Out:
# ['https://baike.baidu.com/item/阿尔巴尼亚共和国',
#  'https://baike.baidu.com/item/阿尔及利亚民主人民共和国',
#  'https://baike.baidu.com/item/阿富汗伊斯兰国',
#  'https://baike.baidu.com/item/阿根廷共和国',
#  'https://baike.baidu.com/item/阿拉伯联合酋长国',
#  'https://baike.baidu.com/item/阿鲁巴',
#  'https://baike.baidu.com/item/阿曼苏丹国',
#  'https://baike.baidu.com/item/阿塞拜疆共和国',
#  'https://baike.baidu.com/item/阿拉伯埃及共和国',
#  'https://baike.baidu.com/item/埃塞俄比亚联邦民主共和国',
#  'https://baike.baidu.com/item/爱尔兰',
#  'https://baike.baidu.com/item/爱沙尼亚共和国',
#  'https://baike.baidu.com/item/安道尔公国',
#  'https://baike.baidu.com/item/安哥拉共和国',
#  'https://baike.baidu.com/item/安圭拉',
#  'https://baike.baidu.com/item/安提瓜和巴布达',
#  'https://baike.baidu.com/item/奥地利共和国',
#  'https://baike.baidu.com/item/澳大利亚联邦',
#  'https://baike.baidu.com/item/中国澳门特别行政区',
#  'https://baike.baidu.com/item/巴巴多斯',
#  'https://baike.baidu.com/item/巴布亚新几内亚独立国',
#  'https://baike.baidu.com/item/巴哈马联邦',
#  'https://baike.baidu.com/item/巴基斯坦伊斯兰共和国',
#  'https://baike.baidu.com/item/巴拉圭共和国',
#  'https://baike.baidu.com/item/巴勒斯坦国',
#  'https://baike.baidu.com/item/巴林国',
#  'https://baike.baidu.com/item/巴拿马共和国',
#  'https://baike.baidu.com/item/巴西联邦共和国',
#  'https://baike.baidu.com/item/白俄罗斯共和国',
#  'https://baike.baidu.com/item/百慕大群岛',
#  'https://baike.baidu.com/item/保加利亚共和国',
#  'https://baike.baidu.com/item/北马里亚纳自由联邦',
#  'https://baike.baidu.com/item/贝宁共和国',
#  'https://baike.baidu.com/item/比利时王国',
#  'https://baike.baidu.com/item/冰岛共和国',
#  'https://baike.baidu.com/item/波多黎各',
#  'https://baike.baidu.com/item/波斯尼亚和黑塞哥维那共和国',
#  'https://baike.baidu.com/item/波兰共和国',
#  'https://baike.baidu.com/item/玻利维亚共和国',
#  'https://baike.baidu.com/item/伯利兹',
#  'https://baike.baidu.com/item/博茨瓦纳共和国',
#  'https://baike.baidu.com/item/不丹王国',
#  'https://baike.baidu.com/item/布基纳法索',
#  'https://baike.baidu.com/item/布隆迪共和国',
#  'https://baike.baidu.com/item/布维岛Bouvet',
#  'https://baike.baidu.com/item/朝鲜民主主义人民共和国',
#  'https://baike.baidu.com/item/赤道几内亚共和国',
#  'https://baike.baidu.com/item/丹麦王国',
#  'https://baike.baidu.com/item/德意志联邦共和国',
#  'https://baike.baidu.com/item/东帝汶',
#  'https://baike.baidu.com/item/多哥共和国',
#  'https://baike.baidu.com/item/多米尼加共和国',
#  'https://baike.baidu.com/item/多米尼克联邦',
#  'https://baike.baidu.com/item/俄罗斯联邦',
#  'https://baike.baidu.com/item/厄瓜多尔共和国',
#  'https://baike.baidu.com/item/厄立特里亚国',
#  'https://baike.baidu.com/item/法兰西共和国',
#  'https://baike.baidu.com/item/法罗群岛',
#  'https://baike.baidu.com/item/法属波利尼西亚',
#  'https://baike.baidu.com/item/法属圭亚那',
#  'https://baike.baidu.com/item/法属南部领土',
#  'https://baike.baidu.com/item/梵蒂冈城国',
#  'https://baike.baidu.com/item/菲律宾共和国',
#  'https://baike.baidu.com/item/斐济群岛共和国',
#  'https://baike.baidu.com/item/芬兰共和国',
#  'https://baike.baidu.com/item/佛得角共和国',
#  'https://baike.baidu.com/item/福克兰群岛（马尔维纳斯）Falkland',
#  'https://baike.baidu.com/item/冈比亚共和国',
#  'https://baike.baidu.com/item/刚果共和国',
#  'https://baike.baidu.com/item/刚果民主共和国',
#  'https://baike.baidu.com/item/哥伦比亚共和国',
#  'https://baike.baidu.com/item/哥斯达黎加共和国',
#  'https://baike.baidu.com/item/格林纳达',
#  'https://baike.baidu.com/item/格陵兰',
#  'https://baike.baidu.com/item/格鲁吉亚',
#  'https://baike.baidu.com/item/古巴共和国',
#  'https://baike.baidu.com/item/瓜德罗普',
#  'https://baike.baidu.com/item/关岛',
#  'https://baike.baidu.com/item/圭亚那合作共和国',
#  'https://baike.baidu.com/item/哈萨克斯坦共和国',
#  'https://baike.baidu.com/item/海地共和国',
#  'https://baike.baidu.com/item/大韩民国',
#  'https://baike.baidu.com/item/荷兰王国',
#  'https://baike.baidu.com/item/荷属安的列斯',
#  'https://baike.baidu.com/item/赫德岛和麦克唐纳岛Heard',
#  'https://baike.baidu.com/item/洪都拉斯共和国',
#  'https://baike.baidu.com/item/基里巴斯共和国',
#  'https://baike.baidu.com/item/吉布提共和国',
#  'https://baike.baidu.com/item/吉尔吉斯共和国',
#  'https://baike.baidu.com/item/几内亚共和国',
#  'https://baike.baidu.com/item/几内亚比绍共和国',
#  'https://baike.baidu.com/item/加拿大',
#  'https://baike.baidu.com/item/加纳共和国',
#  'https://baike.baidu.com/item/加蓬共和国',
#  'https://baike.baidu.com/item/柬埔寨王国',
#  'https://baike.baidu.com/item/捷克共和国',
#  'https://baike.baidu.com/item/津巴布韦共和国',
#  'https://baike.baidu.com/item/喀麦隆共和国',
#  'https://baike.baidu.com/item/卡塔尔国',
#  'https://baike.baidu.com/item/开曼群岛',
#  'https://baike.baidu.com/item/科科斯（基林）群岛',
#  'https://baike.baidu.com/item/科摩罗伊斯兰联邦共和国',
#  'https://baike.baidu.com/item/科特迪瓦共和国',
#  'https://baike.baidu.com/item/科威特国',
#  'https://baike.baidu.com/item/克罗地亚共和国',
#  'https://baike.baidu.com/item/肯尼亚共和国',
#  'https://baike.baidu.com/item/库克群岛',
#  'https://baike.baidu.com/item/拉脱维亚共和国',
#  'https://baike.baidu.com/item/莱索托王国',
#  'https://baike.baidu.com/item/老挝人民民主共和国',
#  'https://baike.baidu.com/item/黎巴嫩共和国',
#  'https://baike.baidu.com/item/立陶宛共和国',
#  'https://baike.baidu.com/item/利比里亚共和国',
#  'https://baike.baidu.com/item/大阿拉伯利比亚人民社会主义民众国',
#  'https://baike.baidu.com/item/列支敦士登公国',
#  'https://baike.baidu.com/item/留尼汪',
#  'https://baike.baidu.com/item/卢森堡大公国',
#  'https://baike.baidu.com/item/卢旺达共和国',
#  'https://baike.baidu.com/item/罗马尼亚',
#  'https://baike.baidu.com/item/马达加斯加共和国',
#  'https://baike.baidu.com/item/马尔代夫共和国',
#  'https://baike.baidu.com/item/马耳他共和国',
#  'https://baike.baidu.com/item/马拉维共和国',
#  'https://baike.baidu.com/item/马来西亚',
#  'https://baike.baidu.com/item/马里共和国',
#  'https://baike.baidu.com/item/马绍尔群岛共和国',
#  'https://baike.baidu.com/item/马提尼克',
#  'https://baike.baidu.com/item/马约特',
#  'https://baike.baidu.com/item/毛里求斯共和国',
#  'https://baike.baidu.com/item/毛里塔尼亚伊斯兰共和国',
#  'https://baike.baidu.com/item/美利坚合众国',
#  'https://baike.baidu.com/item/美国本土外小岛屿',
#  'https://baike.baidu.com/item/美属萨摩亚',
#  'https://baike.baidu.com/item/美属维尔京群岛',
#  'https://baike.baidu.com/item/蒙古国',
#  'https://baike.baidu.com/item/蒙特塞拉特',
#  'https://baike.baidu.com/item/孟加拉人民共和国',
#  'https://baike.baidu.com/item/秘鲁共和国',
#  'https://baike.baidu.com/item/密克罗尼西亚联邦',
#  'https://baike.baidu.com/item/缅甸联邦',
#  'https://baike.baidu.com/item/摩尔多瓦共和国',
#  'https://baike.baidu.com/item/摩洛哥王国',
#  'https://baike.baidu.com/item/摩纳哥公国',
#  'https://baike.baidu.com/item/莫桑比克共和国',
#  'https://baike.baidu.com/item/墨西哥合众国',
#  'https://baike.baidu.com/item/纳米尼亚',
#  'https://baike.baidu.com/item/南非共和国',
#  'https://baike.baidu.com/item/南极洲',
#  'https://baike.baidu.com/item/南乔治亚岛和南桑德韦奇岛',
#  'https://baike.baidu.com/item/南斯拉夫联盟共和国',
#  'https://baike.baidu.com/item/瑙鲁共和国',
#  'https://baike.baidu.com/item/尼泊尔王国',
#  'https://baike.baidu.com/item/尼加拉瓜共和国',
#  'https://baike.baidu.com/item/尼日尔共和国',
#  'https://baike.baidu.com/item/尼日利亚联邦共和国',
#  'https://baike.baidu.com/item/纽埃',
#  'https://baike.baidu.com/item/挪威王国',
#  'https://baike.baidu.com/item/诺福克岛',
#  'https://baike.baidu.com/item/帕劳共和国',
#  'https://baike.baidu.com/item/皮特凯恩',
#  'https://baike.baidu.com/item/葡萄牙共和国',
#  'https://baike.baidu.com/item/前南斯拉夫马其顿共和国',
#  'https://baike.baidu.com/item/日本国',
#  'https://baike.baidu.com/item/瑞典王国',
#  'https://baike.baidu.com/item/瑞士联邦',
#  'https://baike.baidu.com/item/萨尔瓦多共和国',
#  'https://baike.baidu.com/item/萨摩亚独立国',
#  'https://baike.baidu.com/item/塞拉利昂共和国',
#  'https://baike.baidu.com/item/塞内加尔共和国',
#  'https://baike.baidu.com/item/塞浦路斯共和国',
#  'https://baike.baidu.com/item/塞舌尔共和国',
#  'https://baike.baidu.com/item/沙特阿拉伯王国',
#  'https://baike.baidu.com/item/圣诞岛',
#  'https://baike.baidu.com/item/圣多美和普林西比民主共和国',
#  'https://baike.baidu.com/item/圣赫勒拿',
#  'https://baike.baidu.com/item/圣基茨和尼维斯联邦',
#  'https://baike.baidu.com/item/圣卢西亚',
#  'https://baike.baidu.com/item/圣马力诺共和国',
#  'https://baike.baidu.com/item/圣皮埃尔和密克隆Saint',
#  'https://baike.baidu.com/item/圣文森特和格林纳丁斯',
#  'https://baike.baidu.com/item/斯里兰卡民主社会主义共和国',
#  'https://baike.baidu.com/item/斯洛伐克共和国',
#  'https://baike.baidu.com/item/斯洛文尼亚共和国',
#  'https://baike.baidu.com/item/斯瓦尔巴岛和扬马延岛Svalbard',
#  'https://baike.baidu.com/item/斯威士兰王国',
#  'https://baike.baidu.com/item/苏丹共和国',
#  'https://baike.baidu.com/item/苏里南共和国',
#  'https://baike.baidu.com/item/所罗门群岛',
#  'https://baike.baidu.com/item/索马里共和国',
#  'https://baike.baidu.com/item/塔吉克斯坦共和国',
#  'https://baike.baidu.com/item/中国台湾',
#  'https://baike.baidu.com/item/泰王国',
#  'https://baike.baidu.com/item/坦桑尼亚联合共和国',
#  'https://baike.baidu.com/item/汤加王国',
#  'https://baike.baidu.com/item/特克斯和凯科斯群岛',
#  'https://baike.baidu.com/item/特立尼达和多巴哥共和国',
#  'https://baike.baidu.com/item/突尼斯共和国',
#  'https://baike.baidu.com/item/图瓦卢',
#  'https://baike.baidu.com/item/土耳其共和国',
#  'https://baike.baidu.com/item/土库曼斯坦',
#  'https://baike.baidu.com/item/托克劳',
#  'https://baike.baidu.com/item/瓦利斯和富图纳',
#  'https://baike.baidu.com/item/瓦努阿图共和国',
#  'https://baike.baidu.com/item/危地马拉共和国',
#  'https://baike.baidu.com/item/委内瑞拉共和国',
#  'https://baike.baidu.com/item/文莱达鲁萨兰国',
#  'https://baike.baidu.com/item/乌干达共和国',
#  'https://baike.baidu.com/item/乌克兰',
#  'https://baike.baidu.com/item/乌拉圭东岸共和国',
#  'https://baike.baidu.com/item/乌兹别克斯坦',
#  'https://baike.baidu.com/item/西班牙王国',
#  'https://baike.baidu.com/item/西撒哈拉',
#  'https://baike.baidu.com/item/希腊共和国',
#  'https://baike.baidu.com/item/中国香港特别行政区',
#  'https://baike.baidu.com/item/新加坡共和国',
#  'https://baike.baidu.com/item/新喀里多尼亚',
#  'https://baike.baidu.com/item/新西兰',
#  'https://baike.baidu.com/item/匈牙利共和国',
#  'https://baike.baidu.com/item/阿拉伯叙利亚共和国',
#  'https://baike.baidu.com/item/牙买加',
#  'https://baike.baidu.com/item/亚美尼亚共和国',
#  'https://baike.baidu.com/item/也门共和国',
#  'https://baike.baidu.com/item/伊拉克共和国',
#  'https://baike.baidu.com/item/伊朗伊斯兰共和国',
#  'https://baike.baidu.com/item/以色列国',
#  'https://baike.baidu.com/item/意大利共和国',
#  'https://baike.baidu.com/item/印度共和国',
#  'https://baike.baidu.com/item/印度尼西亚共和国',
#  'https://baike.baidu.com/item/大不列颠及北爱尔兰联合王国',
#  'https://baike.baidu.com/item/英属维尔京群岛',
#  'https://baike.baidu.com/item/英属印度洋领地',
#  'https://baike.baidu.com/item/约旦哈希姆王国',
#  'https://baike.baidu.com/item/越南社会主义共和国',
#  'https://baike.baidu.com/item/赞比亚共和国',
#  'https://baike.baidu.com/item/乍得共和国',
#  'https://baike.baidu.com/item/直布罗陀',
#  'https://baike.baidu.com/item/智利共和国',
#  'https://baike.baidu.com/item/中非共和国',
#  'https://baike.baidu.com/item/中华人民共和国']

# %%
all_country_data = []
for idx, url in enumerate(country_url):
    data = get_data(url, headers)
    all_country_data.append(data)
    print("finish {}\{}".format(idx, len(country_url)-1))
# Out:
# finish 0\238
# finish 1\238

# %%
import json
def data2json(data,prefix):
    data_json = json.dumps(data,ensure_ascii=False)
    json.dump(data_json,open('./{}_data.json'.format(prefix), 'w'))
def json2data(prefix):
    data_json = json.load(open('./{}_data.json'.format(prefix)))
    return json.loads(data_json)

# %%
# for relaiton extraction
spot2city = {}
for city in city_data:
    try:
        spots = city.get('著名景点').split('、')[:-1]
        for spot in spots:
            spot2city[spot] = city.get('中文名称')
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2c8478f14aa8> in <module>()
#       1 # for relaiton extraction
#       2 spot2city = {}
# ----> 3 for city in city_data:
#       4     try:
#       5         spots = city.get('著名景点').split('、')[:-1]
#
# NameError: name 'city_data' is not defined

# %%
data2json(all_country_data, 'country')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-148c28986a60> in <module>()
# ----> 1 data2json(all_country_data, 'country')
#
# NameError: name 'data2json' is not defined

# %%
# 实体1， 实体2， 关系， 种类1， 种类2
relation1 = '位于'
relation2 = '著名景点'
type1 = '景点'
type2 = '城市'
relation_path1 = './spot_city_relation.txt'
relation_path2 = './city_spot_relation.txt'
f1 = open(relation_path1, 'w')
f2 = open(relation_path2, 'w')
for spot in all_spot:
    try:
        city = spot2city[spot]
        if '中山' in city or '威海' in city or '，' in spot or ',' in spot:
            print(spot)
            continue
        f1.write("{},{},{},{},{}\n".format(spot,city,relation1,type1,type2))
        f2.write("{},{},{},{},{}\n".format(city,spot,relation2,type2,type1))
    except:
        print(city)
f1.close()
f2.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-181c6a2a69d3> in <module>()
#       8 f1 = open(relation_path1, 'w')
#       9 f2 = open(relation_path2, 'w')
# ---> 10 for spot in all_spot:
#      11     try:
#      12         city = spot2city[spot]
#
# NameError: name 'all_spot' is not defined
